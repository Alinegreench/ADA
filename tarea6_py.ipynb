# %%
def calcular_frecuencias(texto):
    frecuencias = {}
    for caracter in texto:
        if caracter in frecuencias:
            frecuencias[caracter] += 1
        else:
            frecuencias[caracter] = 1
    return frecuencias


def mostrar_tabla_frecuencias(frecuencias):
    print("TABLA DE FRECUENCIAS")
    print(f"{'Carácter':<15} {'Frecuencia':<15}")
    
    total = sum(frecuencias.values())
    for caracter, freq in sorted(frecuencias.items(), key=lambda x: x[1], reverse=True):
        if caracter == ' ':
            print(f"{'[ESPACIO]':<15} {freq:<15}")
        elif caracter == '\n':
            print(f"{'[SALTO]':<15} {freq:<15}")
        else:
            print(f"{caracter:<15} {freq:<15}")
    print("-"*30)


def crear_nodo(caracter, frecuencia, izquierdo=None, derecho=None):
    #crea un nodo como un diccionario
    return {
        'caracter': caracter,
        'frecuencia': frecuencia,
        'izquierdo': izquierdo,
        'derecho': derecho
    }


def construir_arbol_huffman(frecuencias):
    # Crear lista de nodos iniciales
    nodos = []
    for caracter, frecuencia in frecuencias.items():
        nodos.append(crear_nodo(caracter, frecuencia))
    
    print("CONSTRUCCIÓN DEL ÁRBOL DE HUFFMAN")

    iteracion = 1
    print(f"\nEstado inicial: {len(nodos)} nodos")
    mostrar_nodos(nodos)
    
    # Construir el árbol combinando los dos nodos de menor frecuencia
    while len(nodos) > 1:
        nodos.sort(key=lambda x: x['frecuencia'])
        
        izquierdo = nodos.pop(0)
        derecho = nodos.pop(0)
        
        # nuevo nodo combinado
        nuevo_nodo = crear_nodo(
            None, 
            izquierdo['frecuencia'] + derecho['frecuencia'],
            izquierdo,
            derecho
        )
        
        nodos.append(nuevo_nodo)
        
        print(f"\n--- Iteración {iteracion} ---")
        print(f"Combinando: {obtener_nombre_nodo(izquierdo)} (freq: {izquierdo['frecuencia']}) + "
              f"{obtener_nombre_nodo(derecho)} (freq: {derecho['frecuencia']})")
        print(f"Nuevo nodo con frecuencia: {nuevo_nodo['frecuencia']}")
        print(f"Nodos restantes: {len(nodos)}")
        mostrar_nodos(nodos)
        
        iteracion += 1
    
    print("-"*30)
    return nodos[0]


def obtener_nombre_nodo(nodo):
    if nodo['caracter'] is not None:
        if nodo['caracter'] == ' ':
            return '[ESPACIO]'
        elif nodo['caracter'] == '\n':
            return '[SALTO]'
        else:
            return f"'{nodo['caracter']}'"
    else:
        return '[NODO INTERNO]'


def mostrar_nodos(nodos):
    for nodo in nodos:
        nombre = obtener_nombre_nodo(nodo)
        print(f"  {nombre}: frecuencia = {nodo['frecuencia']}")


def generar_codigos(nodo, codigo_actual='', codigos=None):
    if codigos is None:
        codigos = {}
    
    # Si es un nodo hoja (tiene carácter), guardar el código
    if nodo['caracter'] is not None:
        codigos[nodo['caracter']] = codigo_actual if codigo_actual else '0'
        return codigos
    
    if nodo['izquierdo'] is not None:
        generar_codigos(nodo['izquierdo'], codigo_actual + '0', codigos)
    
    if nodo['derecho'] is not None:
        generar_codigos(nodo['derecho'], codigo_actual + '1', codigos)
    
    return codigos


def mostrar_codigos(codigos):
    print("CÓDIGOS DE HUFFMAN (Libres de Prefijo)")
    print(f"{'Carácter':<15} {'Código':<15} {'Longitud'}")
    print("-"*30)
    
    for caracter, codigo in sorted(codigos.items(), key=lambda x: len(x[1])):
        if caracter == ' ':
            print(f"{'[ESPACIO]':<15} {codigo:<15} {len(codigo)}")
        elif caracter == '\n':
            print(f"{'[SALTO]':<15} {codigo:<15} {len(codigo)}")
        else:
            print(f"{caracter:<15} {codigo:<15} {len(codigo)}")
    print("="*50)


def codificar_texto(texto, codigos):
    texto_codificado = ''
    for caracter in texto:
        texto_codificado += codigos[caracter]
    return texto_codificado


def calcular_tasa_compresion(texto_original, texto_codificado):
    bits_originales = len(texto_original) * 8  
    bits_codificados = len(texto_codificado)
    tasa_compresion = ((bits_originales - bits_codificados) / bits_originales) * 100
    
    print("ANÁLISIS DE COMPRESIÓN")
    print(f"Caracteres en el texto: {len(texto_original)}")
    print(f"Bits originales (8 bits/carácter): {bits_originales} bits")
    print(f"Bits después de Huffman: {bits_codificados} bits")
    print(f"Bits ahorrados: {bits_originales - bits_codificados} bits")
    print(f"Tasa de compresión: {tasa_compresion:.2f}%")
    print(f"Tamaño relativo: {(bits_codificados/bits_originales)*100:.2f}%")
    print("-"*30)


def comprimir_archivo(nombre_archivo):
    try:
        with open(nombre_archivo, 'r', encoding='utf-8') as archivo:
            texto = archivo.read()
        
        if not texto:
            print("El archivo está vacío.")
            return
        
        print(f"\nArchivo '{nombre_archivo}' cargado exitosamente.")
        print(f"Tamaño del texto: {len(texto)} caracteres")
        
        comprimir_texto(texto)
        
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo '{nombre_archivo}'")
    except Exception as e:
        print(f"Error al leer el archivo: {e}")


def comprimir_texto(texto):
    frecuencias = calcular_frecuencias(texto)
    mostrar_tabla_frecuencias(frecuencias)
    
    arbol = construir_arbol_huffman(frecuencias)
    
    codigos = generar_codigos(arbol)
    mostrar_codigos(codigos)
    
    texto_codificado = codificar_texto(texto, codigos)
    
    print("TEXTO CODIFICADO")
    
    # Mostrar solo los primeros 500 caracteres si es muy largo
    if len(texto_codificado) > 500:
        print(texto_codificado[:500] + "...")
        print(f"\n(Mostrando solo los primeros 500 bits de {len(texto_codificado)} totales)")
    else:
        print(texto_codificado)
    print("="*50)
    
    calcular_tasa_compresion(texto, texto_codificado)
    
    return texto_codificado, codigos

def main():
    print("PROGRAMA DE CODIFICACIÓN HUFFMAN")

    print("\n¿Qué deseas hacer?")
    print("1. Comprimir texto introducido manualmente")
    print("2. Comprimir archivo de texto")
    
    opcion = input("\nElige una opción: ").strip()
    
    if opcion == '1':
        texto = input("Introduce el texto a comprimir: ")
        
        if not texto:
            print("No se introdujo ningún texto.")
        else:
            comprimir_texto(texto)
    
    elif opcion == '2':
        nombre_archivo = input("Introduce el nombre del archivo (ej: texto.txt): ").strip()
        comprimir_archivo(nombre_archivo)
    
    else:
        print("Opción no válida. El programa finalizará.")

if __name__ == "__main__":
    main()
# Out:
# PROGRAMA DE CODIFICACIÓN HUFFMAN
#
# ¿Qué deseas hacer?
# 1. Comprimir texto introducido manualmente
# 2. Comprimir archivo de texto
# TABLA DE FRECUENCIAS
# Carácter        Frecuencia
# g               8
# [ESPACIO]       7
# d               6
# f               6
# m               5
# i               4
# k               4
# s               3
# h               3
# a               3
# t               3
# o               3
# n               2
# e               2
# r               2
# u               2
# z               2
# w               1
# v               1
# q               1
# b               1
# l               1
# j               1
# ,               1
# ------------------------------
# CONSTRUCCIÓN DEL ÁRBOL DE HUFFMAN
#
# Estado inicial: 24 nodos
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   'g': frecuencia = 8
#   [ESPACIO]: frecuencia = 7
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'n': frecuencia = 2
#   'e': frecuencia = 2
#   'r': frecuencia = 2
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'w': frecuencia = 1
#   'm': frecuencia = 5
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   'u': frecuencia = 2
#   'z': frecuencia = 2
#   'v': frecuencia = 1
#   'q': frecuencia = 1
#   'b': frecuencia = 1
#   'l': frecuencia = 1
#   'o': frecuencia = 3
#   'j': frecuencia = 1
#   ',': frecuencia = 1
#
# --- Iteración 1 ---
# Combinando: 'w' (freq: 1) + 'v' (freq: 1)
# Nuevo nodo con frecuencia: 2
# Nodos restantes: 23
#   'q': frecuencia = 1
#   'b': frecuencia = 1
#   'l': frecuencia = 1
#   'j': frecuencia = 1
#   ',': frecuencia = 1
#   'n': frecuencia = 2
#   'e': frecuencia = 2
#   'r': frecuencia = 2
#   'u': frecuencia = 2
#   'z': frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 2
#
# --- Iteración 2 ---
# Combinando: 'q' (freq: 1) + 'b' (freq: 1)
# Nuevo nodo con frecuencia: 2
# Nodos restantes: 22
#   'l': frecuencia = 1
#   'j': frecuencia = 1
#   ',': frecuencia = 1
#   'n': frecuencia = 2
#   'e': frecuencia = 2
#   'r': frecuencia = 2
#   'u': frecuencia = 2
#   'z': frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 2
#
# --- Iteración 3 ---
# Combinando: 'l' (freq: 1) + 'j' (freq: 1)
# Nuevo nodo con frecuencia: 2
# Nodos restantes: 21
#   ',': frecuencia = 1
#   'n': frecuencia = 2
#   'e': frecuencia = 2
#   'r': frecuencia = 2
#   'u': frecuencia = 2
#   'z': frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 2
#
# --- Iteración 4 ---
# Combinando: ',' (freq: 1) + 'n' (freq: 2)
# Nuevo nodo con frecuencia: 3
# Nodos restantes: 20
#   'e': frecuencia = 2
#   'r': frecuencia = 2
#   'u': frecuencia = 2
#   'z': frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 3
#
# --- Iteración 5 ---
# Combinando: 'e' (freq: 2) + 'r' (freq: 2)
# Nuevo nodo con frecuencia: 4
# Nodos restantes: 19
#   'u': frecuencia = 2
#   'z': frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   [NODO INTERNO]: frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 4
#
# --- Iteración 6 ---
# Combinando: 'u' (freq: 2) + 'z' (freq: 2)
# Nuevo nodo con frecuencia: 4
# Nodos restantes: 18
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   [NODO INTERNO]: frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   [NODO INTERNO]: frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 4
#
# --- Iteración 7 ---
# Combinando: [NODO INTERNO] (freq: 2) + [NODO INTERNO] (freq: 2)
# Nuevo nodo con frecuencia: 4
# Nodos restantes: 17
#   [NODO INTERNO]: frecuencia = 2
#   's': frecuencia = 3
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   [NODO INTERNO]: frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 4
#
# --- Iteración 8 ---
# Combinando: [NODO INTERNO] (freq: 2) + 's' (freq: 3)
# Nuevo nodo con frecuencia: 5
# Nodos restantes: 16
#   'h': frecuencia = 3
#   'a': frecuencia = 3
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   [NODO INTERNO]: frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 5
#
# --- Iteración 9 ---
# Combinando: 'h' (freq: 3) + 'a' (freq: 3)
# Nuevo nodo con frecuencia: 6
# Nodos restantes: 15
#   't': frecuencia = 3
#   'o': frecuencia = 3
#   [NODO INTERNO]: frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   [NODO INTERNO]: frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 6
#
# --- Iteración 10 ---
# Combinando: 't' (freq: 3) + 'o' (freq: 3)
# Nuevo nodo con frecuencia: 6
# Nodos restantes: 14
#   [NODO INTERNO]: frecuencia = 3
#   'i': frecuencia = 4
#   'k': frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   [NODO INTERNO]: frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 6
#
# --- Iteración 11 ---
# Combinando: [NODO INTERNO] (freq: 3) + 'i' (freq: 4)
# Nuevo nodo con frecuencia: 7
# Nodos restantes: 13
#   'k': frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   [NODO INTERNO]: frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 7
#
# --- Iteración 12 ---
# Combinando: 'k' (freq: 4) + [NODO INTERNO] (freq: 4)
# Nuevo nodo con frecuencia: 8
# Nodos restantes: 12
#   [NODO INTERNO]: frecuencia = 4
#   [NODO INTERNO]: frecuencia = 4
#   'm': frecuencia = 5
#   [NODO INTERNO]: frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   [NODO INTERNO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#
# --- Iteración 13 ---
# Combinando: [NODO INTERNO] (freq: 4) + [NODO INTERNO] (freq: 4)
# Nuevo nodo con frecuencia: 8
# Nodos restantes: 11
#   'm': frecuencia = 5
#   [NODO INTERNO]: frecuencia = 5
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   [NODO INTERNO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#
# --- Iteración 14 ---
# Combinando: 'm' (freq: 5) + [NODO INTERNO] (freq: 5)
# Nuevo nodo con frecuencia: 10
# Nodos restantes: 10
#   'd': frecuencia = 6
#   'f': frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   [NODO INTERNO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 10
#
# --- Iteración 15 ---
# Combinando: 'd' (freq: 6) + 'f' (freq: 6)
# Nuevo nodo con frecuencia: 12
# Nodos restantes: 9
#   [NODO INTERNO]: frecuencia = 6
#   [NODO INTERNO]: frecuencia = 6
#   [ESPACIO]: frecuencia = 7
#   [NODO INTERNO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 10
#   [NODO INTERNO]: frecuencia = 12
#
# --- Iteración 16 ---
# Combinando: [NODO INTERNO] (freq: 6) + [NODO INTERNO] (freq: 6)
# Nuevo nodo con frecuencia: 12
# Nodos restantes: 8
#   [ESPACIO]: frecuencia = 7
#   [NODO INTERNO]: frecuencia = 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 10
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 12
#
# --- Iteración 17 ---
# Combinando: [ESPACIO] (freq: 7) + [NODO INTERNO] (freq: 7)
# Nuevo nodo con frecuencia: 14
# Nodos restantes: 7
#   'g': frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 10
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 14
#
# --- Iteración 18 ---
# Combinando: 'g' (freq: 8) + [NODO INTERNO] (freq: 8)
# Nuevo nodo con frecuencia: 16
# Nodos restantes: 6
#   [NODO INTERNO]: frecuencia = 8
#   [NODO INTERNO]: frecuencia = 10
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 14
#   [NODO INTERNO]: frecuencia = 16
#
# --- Iteración 19 ---
# Combinando: [NODO INTERNO] (freq: 8) + [NODO INTERNO] (freq: 10)
# Nuevo nodo con frecuencia: 18
# Nodos restantes: 5
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 12
#   [NODO INTERNO]: frecuencia = 14
#   [NODO INTERNO]: frecuencia = 16
#   [NODO INTERNO]: frecuencia = 18
#
# --- Iteración 20 ---
# Combinando: [NODO INTERNO] (freq: 12) + [NODO INTERNO] (freq: 12)
# Nuevo nodo con frecuencia: 24
# Nodos restantes: 4
#   [NODO INTERNO]: frecuencia = 14
#   [NODO INTERNO]: frecuencia = 16
#   [NODO INTERNO]: frecuencia = 18
#   [NODO INTERNO]: frecuencia = 24
#
# --- Iteración 21 ---
# Combinando: [NODO INTERNO] (freq: 14) + [NODO INTERNO] (freq: 16)
# Nuevo nodo con frecuencia: 30
# Nodos restantes: 3
#   [NODO INTERNO]: frecuencia = 18
#   [NODO INTERNO]: frecuencia = 24
#   [NODO INTERNO]: frecuencia = 30
#
# --- Iteración 22 ---
# Combinando: [NODO INTERNO] (freq: 18) + [NODO INTERNO] (freq: 24)
# Nuevo nodo con frecuencia: 42
# Nodos restantes: 2
#   [NODO INTERNO]: frecuencia = 30
#   [NODO INTERNO]: frecuencia = 42
#
# --- Iteración 23 ---
# Combinando: [NODO INTERNO] (freq: 30) + [NODO INTERNO] (freq: 42)
# Nuevo nodo con frecuencia: 72
# Nodos restantes: 1
#   [NODO INTERNO]: frecuencia = 72
# ------------------------------
# CÓDIGOS DE HUFFMAN (Libres de Prefijo)
# Carácter        Código          Longitud
# ------------------------------
# [ESPACIO]       000             3
# g               010             3
# i               0011            4
# k               0110            4
# m               1010            4
# d               1100            4
# f               1101            4
# ,               00100           5
# n               00101           5
# e               01110           5
# r               01111           5
# u               10000           5
# z               10001           5
# s               10111           5
# h               11100           5
# a               11101           5
# t               11110           5
# o               11111           5
# w               100100          6
# v               100101          6
# q               100110          6
# b               100111          6
# l               101100          6
# j               101101          6
# ==================================================
# TEXTO CODIFICADO
# 
# ==================================================
# ANÁLISIS DE COMPRESIÓN
# Caracteres en el texto: 72
# Bits originales (8 bits/carácter): 576 bits
# Bits después de Huffman: 311 bits
# Bits ahorrados: 265 bits
# Tasa de compresión: 46.01%
# Tamaño relativo: 53.99%
# ------------------------------
